# %%
import mglearn

mglearn.plots.plot_agglomerative_algorithm()

# %%
import mglearn
import matplotlib.pyplot as plt
from sklearn.cluster import AgglomerativeClustering
from sklearn.datasets import make_blobs
from sklearn.datasets import make_moons

X, y = make_blobs(random_state=1)

agg = AgglomerativeClustering(n_clusters=3)
assignment = agg.fit_predict(X)

mglearn.discrete_scatter(X[:, 0], X[:, 1], assignment)
plt.xlabel("Feature 1")
plt.ylabel("Feature 2")
plt.legend(["cluster 1", "cluster2", "cluster3"], loc="best")

#But it fails still to generalize the two moons dataset

X_moon, y_moon = make_moons(random_state=1)

agg_moon = AgglomerativeClustering(n_clusters=2)
assignment_moon = agg_moon.fit_predict(X_moon)

fig, axes = plt.subplots(1, 1, figsize=(6, 4), subplot_kw={'xticks':(), 'yticks':()})
mglearn.discrete_scatter(X_moon[:, 0], X_moon[:, 1], assignment_moon)
plt.xlabel("Feature 1")
plt.ylabel("Feature 2")
plt.title("Make moons dataset")
# Out:
# Text(0.5, 1.0, 'Make moons dataset')

# %%
import mglearn

mglearn.plots.plot_agglomerative()

# %%
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs
from scipy.cluster.hierarchy import dendrogram, ward

X, y = make_blobs(random_state=0, n_samples=12)

#apply the ward clustering to the data array X
#scipy ward function returns as array that specifies the distance
#bridged when performing agglomerative clustering

linkage_array = ward(X)

#now we plot the dendrogram for the linkage array of distances
#between clusters

dendrogram(linkage_array)

#mark the cuts in the tree that specifies two or three clusters

ax = plt.gca()
bounds = ax.get_xbound()
ax.plot(bounds, [7.25, 7.25], '--', c='k')
ax.plot(bounds, [4, 4], '--', c='k')

ax.text(bounds[1], 7.25, 'two clusters', va='center', fontdict={'size':15})
ax.text(bounds[1], 4, 'three clusters', va='center', fontdict={'size':15})
plt.xlabel("sample index")
plt.ylabel("cluster distance")
# Out:
# Text(0, 0.5, 'cluster distance')
